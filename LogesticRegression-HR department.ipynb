# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('HR_comma_sep.csv')

# %%
from sqlalchemy import create_engine

# Load the SQL extension
# %load_ext sql

# Create an engine instance for SQLite
engine = create_engine('sqlite:///my_database.db')

# Load DataFrame into SQL
df.to_sql('hr', con=engine, if_exists='replace', index=False)
# Out:
# 14999

# %%
# %sql sqlite:///my_database.db

# %%
# %sql select * from hr limit 5;
# Out:
#  * sqlite:///my_database.db
# Done.
# [(0.38, 0.53, 2, 157, 3, 0, 1, 0, 'sales', 'low'),
#  (0.8, 0.86, 5, 262, 6, 0, 1, 0, 'sales', 'medium'),
#  (0.11, 0.88, 7, 272, 4, 0, 1, 0, 'sales', 'medium'),
#  (0.72, 0.87, 5, 223, 5, 0, 1, 0, 'sales', 'low'),
#  (0.37, 0.52, 2, 159, 3, 0, 1, 0, 'sales', 'low')]

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# count         14999.000000     14999.000000    14999.000000
# unique                 NaN              NaN             NaN
# top                    NaN              NaN             NaN
# freq                   NaN              NaN             NaN
# mean              0.612834         0.716102        3.803054
# std               0.248631         0.171169        1.232592
# min               0.090000         0.360000        2.000000
# 25%               0.440000         0.560000        3.000000
# 50%               0.640000         0.720000        4.000000
# 75%               0.820000         0.870000        5.000000
# max               1.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident          left  \
# count           14999.000000        14999.000000   14999.000000  14999.000000
# unique                   NaN                 NaN            NaN           NaN
# ...

# %%
sns.boxplot(x='Department',y='left',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='left'>

# %%
# %sql select department,count(left) from hr where left=1 group by department;
# Out:
#  * sqlite:///my_database.db
# Done.
# [('IT', 273),
#  ('RandD', 121),
#  ('accounting', 204),
#  ('hr', 215),
#  ('management', 91),
#  ('marketing', 203),
#  ('product_mng', 198),
#  ('sales', 1014),
#  ('support', 555),
#  ('technical', 697)]

# %%
# %sql select salary,count(left) from hr where left=1 group by salary;
# Out:
#  * sqlite:///my_database.db
# Done.
# [('high', 82), ('low', 2172), ('medium', 1317)]

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (14999, 10)

# %%
box=df.iloc[:,:8]
box.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years'],
#       dtype='object')

# %%
plt.figure(figsize=(10,3))
sns.heatmap(box.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
p=1
for i in box.columns:
    plt.subplot(2,4,p)
    plt.scatter(df[i],df['left'])
    plt.title(i)
    p+=1

# %%
# %sql select left,avg(promotion_last_5years) from hr group by left;
# Out:
#  * sqlite:///my_database.db
# Done.
# [(0, 0.026251312565628283), (1, 0.005320638476617194)]

# %%
df1=df.iloc[:,:8]

# %%
df1.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df['salary'],df['left']).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
sns.histplot(x='Department',hue='left',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
salary=pd.get_dummies(df['salary'])
salary
# Out:
#         high    low  medium
# 0      False   True   False
# 1      False  False    True
# 2      False  False    True
# 3      False   True   False
# 4      False   True   False
# ...      ...    ...     ...
# 14994  False   True   False
# 14995  False   True   False
# 14996  False   True   False
# 14997  False   True   False
# 14998  False   True   False
#
# [14999 rows x 3 columns]

# %%
for i in salary.columns:
    salary[i]=salary[i].astype(int)
salary
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
df=pd.concat([df,salary],axis=1)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
x=df.loc[:,['satisfaction_level','average_montly_hours','promotion_last_5years','high','medium']]
x.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                0.38                   157                      0     0
# 1                0.80                   262                      0     0
# 2                0.11                   272                      0     0
# 3                0.72                   223                      0     0
# 4                0.37                   159                      0     0
#
#    medium
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0

# %%
y=df['left']

# %%
x=x.values

# %%
y=y.values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.7745645470455871

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
y_pred=model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.773

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[2126,  161],
#        [ 520,  193]])

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
